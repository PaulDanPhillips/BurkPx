# %% [markdown]
# # OverSampled Analysis

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import RandomOverSampler
from sklearn.linear_model import LogisticRegression
import scipy.stats as stats
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import balanced_accuracy_score

# %% [markdown]
# ## Best Models By 10-fold CV
# ### Week 1-4

# %%
############################################### WEEK 1 #########################################

LR = pd.read_csv('W1_EnetBurkPx_GridSearch.txt', sep='\t', index_col=0)
W1Enet = LR.loc[LR['params'] =="{'C': 0.0021544346900318843, 'l1_ratio': 0.3666666666666667}"]
W1Enet['Model']  = 'ElasticNet'
W1Enet['TimeGroup']  = 'Week1'

LR = pd.read_csv('W1_LRBurkPx_GridSearch.txt', sep='\t', index_col=0)
W1LASSOWeak=LR.loc[LR['params']== "{'C': 1000.0, 'penalty': 'l1'}"].copy()
W1LASSOWeak['Model'] = 'LASSO_Weak'
W1LASSOWeak['TimeGroup']  = 'Week1'

W1LASSOstrong=LR.loc[LR['params']== "{'C': 0.004641588833612777, 'penalty': 'l1'}"].copy()
W1LASSOstrong['Model'] = 'LASSO_Strong'
W1LASSOstrong['TimeGroup']  = 'Week1'

W1RIDGEWeak=LR.loc[LR['params']== "{'C': 1000.0, 'penalty': 'l2'}"].copy()
W1RIDGEWeak['Model'] = 'Ridge_Weak'
W1RIDGEWeak['TimeGroup']  = 'Week1'


W1RIDGEstrong=LR.loc[LR['params']== "{'C': 0.004641588833612777, 'penalty': 'l2'}"].copy()
W1RIDGEstrong['Model'] = 'Ridge_Strong'
W1RIDGEstrong['TimeGroup']  = 'Week1'

LR = pd.read_csv('W1_XGBBurkPx_GridSearch.txt', sep='\t', index_col=0)
W1XGB = LR.loc[LR['params']=="{'colsample_bytree': 0.05, 'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 25, 'subsample': 0.2}"]
W1XGB['Model'] = 'XGBoost'
W1XGB['TimeGroup']  = 'Week1'

############################################### WEEK 2 #########################################


LR = pd.read_csv('W2_EnetBurkPx_GridSearch.txt', sep='\t', index_col=0)
W2Enet = LR.loc[LR['params'] =="{'C': 0.0021544346900318843, 'l1_ratio': 0.6333333333333333}"]
W2Enet['Model']  = 'ElasticNet'
W2Enet['TimeGroup']  = 'Week2'

LR = pd.read_csv('W2_LRBurkPx_GridSearch.txt', sep='\t', index_col=0)
W2LASSOWeak=LR.loc[LR['params']== "{'C': 1000.0, 'penalty': 'l1'}"].copy()
W2LASSOWeak['Model'] = 'LASSO_Weak'
W2LASSOWeak['TimeGroup']  = 'Week2'

W2LASSOstrong=LR.loc[LR['params']== "{'C': 0.004641588833612777, 'penalty': 'l1'}"].copy()
W2LASSOstrong['Model'] = 'LASSO_Strong'
W2LASSOstrong['TimeGroup']  = 'Week2'

W2RIDGEWeak=LR.loc[LR['params']== "{'C': 1000.0, 'penalty': 'l2'}"].copy()
W2RIDGEWeak['Model'] = 'Ridge_Weak'
W2RIDGEWeak['TimeGroup']  = 'Week2'

W2RIDGEstrong=LR.loc[LR['params']== "{'C': 0.004641588833612777, 'penalty': 'l2'}"].copy()
W2RIDGEstrong['Model'] = 'Ridge_Strong'
W2RIDGEstrong['TimeGroup']  = 'Week2'

LR = pd.read_csv('W2_XGBBurkPx_GridSearch.txt', sep='\t', index_col=0)
W2XGB = LR.loc[LR['params']=="{'colsample_bytree': 0.05, 'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.55}"]
W2XGB['Model'] = 'XGBoost'
W2XGB['TimeGroup']  = 'Week2'

############################################### WEEK 3 #########################################


LR = pd.read_csv('W3_EnetBurkPx_GridSearch.txt', sep='\t', index_col=0)
W3Enet = LR.loc[LR['params'] =="{'C': 0.0021544346900318843, 'l1_ratio': 0.6333333333333333}"]
W3Enet['Model']  = 'ElasticNet'
W3Enet['TimeGroup']  = 'Week3'

LR = pd.read_csv('W3_LRBurkPx_GridSearch.txt', sep='\t', index_col=0)
W3LASSOWeak=LR.loc[LR['params']== "{'C': 1000.0, 'penalty': 'l1'}"].copy()
W3LASSOWeak['Model'] = 'LASSO_Weak'
W3LASSOWeak['TimeGroup']  = 'Week3'

W3LASSOstrong=LR.loc[LR['params']== "{'C': 0.004641588833612777, 'penalty': 'l1'}"].copy()
W3LASSOstrong['Model'] = 'LASSO_Strong'
W3LASSOstrong['TimeGroup']  = 'Week3'

W3RIDGEWeak=LR.loc[LR['params']== "{'C': 1000.0, 'penalty': 'l2'}"].copy()
W3RIDGEWeak['Model'] = 'Ridge_Weak'
W3RIDGEWeak['TimeGroup']  = 'Week3'

W3RIDGEstrong=LR.loc[LR['params']== "{'C': 0.004641588833612777, 'penalty': 'l2'}"].copy()
W3RIDGEstrong['Model'] = 'Ridge_Strong'
W3RIDGEstrong['TimeGroup']  = 'Week3'

LR = pd.read_csv('W3_XGBBurkPx_GridSearch.txt', sep='\t', index_col=0)
W3XGB = LR.loc[LR['params']=="{'colsample_bytree': 0.05, 'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.55}"]
W3XGB['Model'] = 'XGBoost'
W3XGB['TimeGroup']  = 'Week3'

############################################### WEEK 4 #########################################


LR = pd.read_csv('W4_EnetBurkPx_GridSearch.txt', sep='\t', index_col=0)
W4Enet = LR.loc[LR['params'] =="{'C': 0.0021544346900318843, 'l1_ratio': 0.6333333333333333}"]
W4Enet['Model']  = 'ElasticNet'
W4Enet['TimeGroup']  = 'Week4'

LR = pd.read_csv('W4_LRBurkPx_GridSearch.txt', sep='\t', index_col=0)
W4LASSOWeak=LR.loc[LR['params']== "{'C': 1000.0, 'penalty': 'l1'}"].copy()
W4LASSOWeak['Model'] = 'LASSO_Weak'
W4LASSOWeak['TimeGroup']  = 'Week4'

W4LASSOstrong=LR.loc[LR['params']== "{'C': 0.004641588833612777, 'penalty': 'l1'}"].copy()
W4LASSOstrong['Model'] = 'LASSO_Strong'
W4LASSOstrong['TimeGroup']  = 'Week4'

W4RIDGEWeak=LR.loc[LR['params']== "{'C': 1000.0, 'penalty': 'l2'}"].copy()
W4RIDGEWeak['Model'] = 'Ridge_Weak'
W4RIDGEWeak['TimeGroup']  = 'Week4'

W4RIDGEstrong=LR.loc[LR['params']== "{'C': 0.004641588833612777, 'penalty': 'l2'}"].copy()
W4RIDGEstrong['Model'] = 'Ridge_Strong'
W4RIDGEstrong['TimeGroup']  = 'Week4'

LR = pd.read_csv('W4_XGBBurkPx_GridSearch.txt', sep='\t', index_col=0)
W4XGB = LR.loc[LR['params']=="{'colsample_bytree': 0.05, 'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.55}"]
W4XGB['Model'] = 'XGBoost'
W4XGB['TimeGroup']  = 'Week4'
# Out:
# /var/folders/20/192vzyys2_b6v3q3tlh1tmd40000gn/T/ipykernel_3679/454396990.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   W1Enet['Model']  = 'ElasticNet'
# /var/folders/20/192vzyys2_b6v3q3tlh1tmd40000gn/T/ipykernel_3679/454396990.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   W1Enet['TimeGroup']  = 'Week1'
# /var/folders/20/192vzyys2_b6v3q3tlh1tmd40000gn/T/ipykernel_3679/454396990.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
BEST = pd.concat([W1LASSOWeak, W1LASSOstrong, W1RIDGEWeak, W1RIDGEstrong, W1Enet, W1XGB, W2LASSOWeak, W2LASSOstrong, W2RIDGEWeak, W2RIDGEstrong, W2Enet, W2XGB, W3LASSOWeak, W3LASSOstrong, W3RIDGEWeak, W3RIDGEstrong, W3Enet, W3XGB, W4LASSOWeak, W4LASSOstrong, W4RIDGEWeak, W4RIDGEstrong, W4Enet, W4XGB])

BEST['params2'] = BEST['params'].astype(str)


sns.set_style('darkgrid')
sns.set_palette('colorblind')
fig, ax = plt.subplots()
sns.boxplot(data=BEST, y= 'mean_test_score', x='TimeGroup', hue='Model', ax=ax)
plt.xticks(rotation=45)
ax.set_title('Week1-4 Model Comparions')


fig.savefig('Overall_Model_Comparison_Oversampled_rocAUC.png', bbox_inches='tight', dpi=300)

# %% [markdown]
# ## Validation Set Analysis
# ### Week 1-4

# %%
############################################### WEEK 1 #########################################
from imblearn.under_sampling import RandomUnderSampler

# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html
os.chdir('../../ValidationSet')

df = pd.read_csv('ValidationSet.txt', sep='\t', index_col=0)
Week1 = df.loc[(df['TimeGroup']=='Week1')|(df['TimeGroup']=='Healthy')]

yVAL = Week1.Status.copy()
yVAL.replace('Melioid', 1, inplace=True)
yVAL.replace('Negative', 0, inplace=True)

XVAL = Week1.iloc[:,4:].copy()
XVAL = pd.get_dummies(XVAL)

ros = RandomUnderSampler(random_state=0)
Xunder, Yunder = ros.fit_resample(XVAL, yVAL)

RAND=np.random.RandomState(4)
############ MODELS

enet = LogisticRegression(penalty = 'elasticnet', C=0.0021544346900318843, l1_ratio=0.3666666666666667, solver = 'saga', max_iter=int(1e6)).fit(Xunder, Yunder)
W1Enet = roc_auc_score(Yunder, enet.predict_proba(Xunder)[:, 1])


LR = LogisticRegression(penalty = 'l1', C=0.004641588833612777, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W1LassoStrong = roc_auc_score(Yunder, LR.predict_proba(Xunder)[:, 1])

LR = LogisticRegression(penalty = 'l1', C=1000, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W1LassoWeak = roc_auc_score(Yunder, LR.predict_proba(Xunder)[:, 1])

LR = LogisticRegression(penalty = 'l1', C=0.004641588833612777, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W1RidgeStrong = roc_auc_score(Yunder, LR.predict_proba(Xunder)[:, 1])

LR = LogisticRegression(penalty = 'l1', C=1000, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W1LRidgeWeak = roc_auc_score(Yunder, LR.predict_proba(Xunder)[:, 1])

xgb =  XGBClassifier(objective='binary:logistic', eval_metric='logloss', random_state=RAND,colsample_bytree=0.05, learning_rate=0.001, max_depth=3, n_estimators=25, subsample=0.2).fit(Xunder,Yunder)
W1XGB = roc_auc_score(Yunder, xgb.predict_proba(Xunder)[:, 1])


############################################### WEEK 2 #########################################

enet = LogisticRegression(penalty = 'elasticnet', C=0.0021544346900318843, l1_ratio=0.6333333333333333, solver = 'saga', max_iter=int(1e6)).fit(Xunder, Yunder)
W2Enet = roc_auc_score(Yunder, enet.predict_proba(Xunder)[:, 1])

LR = LogisticRegression(penalty = 'l1', C=0.004641588833612777, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W2LassoStrong = roc_auc_score(Yunder, LR.predict_proba(Xunder)[:, 1])

LR = LogisticRegression(penalty = 'l1', C=1000, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W2LassoWeak = roc_auc_score(Yunder, LR.predict_proba(Xunder)[:, 1])

LR = LogisticRegression(penalty = 'l1', C=0.004641588833612777, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W2RidgeStrong = roc_auc_score(Yunder, LR.predict_proba(Xunder)[:, 1])

LR = LogisticRegression(penalty = 'l1', C=1000, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W2LRidgeWeak = roc_auc_score(Yunder, LR.predict_proba(Xunder)[:, 1])

xgb =  XGBClassifier(objective='binary:logistic', eval_metric='logloss', random_state=RAND,colsample_bytree=0.05, learning_rate=0.001, max_depth=3, n_estimators=50, subsample=0.55).fit(Xunder,Yunder)
W2XGB = roc_auc_score(Yunder, xgb.predict_proba(Xunder)[:, 1])


############################################### WEEK 3 #########################################

enet = LogisticRegression(penalty = 'elasticnet', C=0.0021544346900318843, l1_ratio=0.6333333333333333, solver = 'saga', max_iter=int(1e6)).fit(Xunder, Yunder)
W3Enet = roc_auc_score(Yunder, enet.predict_proba(Xunder)[:, 1])


LR = LogisticRegression(penalty = 'l1', C=0.004641588833612777, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W3LassoStrong = roc_auc_score(Yunder, LR.predict_proba(Xunder)[:, 1])

LR = LogisticRegression(penalty = 'l1', C=1000, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W3LassoWeak = roc_auc_score(Yunder, LR.predict_proba(Xunder)[:, 1])

LR = LogisticRegression(penalty = 'l1', C=0.004641588833612777, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W3RidgeStrong = roc_auc_score(Yunder, LR.predict_proba(Xunder)[:, 1])

LR = LogisticRegression(penalty = 'l1', C=1000, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W3LRidgeWeak = roc_auc_score(Yunder, LR.predict_proba(Xunder)[:, 1])

xgb =  XGBClassifier(objective='binary:logistic', eval_metric='logloss', random_state=RAND,colsample_bytree=0.05, learning_rate=0.001, max_depth=3, n_estimators=50, subsample=0.55).fit(Xunder,Yunder)
W3XGB = roc_auc_score(Yunder, xgb.predict_proba(Xunder)[:, 1])


############################################### WEEK 4 #########################################

enet = LogisticRegression(penalty = 'elasticnet', C=0.0021544346900318843, l1_ratio=0.6333333333333333, solver = 'saga', max_iter=int(1e6)).fit(Xunder, Yunder)
W4Enet = roc_auc_score(Yunder, enet.predict_proba(Xunder)[:, 1])

LR = LogisticRegression(penalty = 'l1', C=0.004641588833612777, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W4LassoStrong = roc_auc_score(Yunder, LR.predict_proba(Xunder)[:, 1])

LR = LogisticRegression(penalty = 'l1', C=1000, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W4LassoWeak = roc_auc_score(Yunder, LR.predict_proba(Xunder)[:, 1])

LR = LogisticRegression(penalty = 'l1', C=0.004641588833612777, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W4RidgeStrong = roc_auc_score(Yunder, LR.predict_proba(Xunder)[:, 1])

LR = LogisticRegression(penalty = 'l1', C=1000, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W4LRidgeWeak = roc_auc_score(Yunder, LR.predict_proba(Xunder)[:, 1])

xgb =  XGBClassifier(objective='binary:logistic', eval_metric='logloss', random_state=RAND,colsample_bytree=0.05, learning_rate=0.001, max_depth=3, n_estimators=50, subsample=0.55).fit(Xunder,Yunder)
W4XGB = roc_auc_score(Yunder, xgb.predict_proba(Xunder)[:, 1])

# %%
Vals = [W1Enet, W1LassoStrong, W1LassoWeak, W1RidgeStrong, W1LRidgeWeak, W1XGB, W2Enet, W2LassoStrong, W2LassoWeak, W2RidgeStrong, W2LRidgeWeak, W2XGB, W3Enet, W3LassoStrong, W3LassoWeak, W3RidgeStrong, W3LRidgeWeak, W3XGB, W4Enet, W4LassoStrong, W4LassoWeak, W4RidgeStrong, W4LRidgeWeak, W4XGB]
Mods = ['Enet', 'LassoStrong', 'LassoWeak', 'RidgeStrong', 'LRidgeWeak', 'XGB', 'Enet', 'LassoStrong', 'LassoWeak', 'RidgeStrong', 'LRidgeWeak', 'XGB', 'Enet', 'LassoStrong', 'LassoWeak', 'RidgeStrong', 'LRidgeWeak', 'XGB', 'Enet', 'LassoStrong', 'LassoWeak', 'RidgeStrong', 'LRidgeWeak', 'XGB']
Times = ['W1', 'W1', 'W1', 'W1', 'W1', 'W1', 'W2', 'W2', 'W2', 'W2', 'W2', 'W2', 'W3', 'W3', 'W3', 'W3', 'W3', 'W3', 'W4', 'W4', 'W4', 'W4', 'W4', 'W4']

DFval = pd.DataFrame({'UnderSampled_AUC':Vals, 'Models':Mods, 'TimeGroup':Times})


fig, ax = plt.subplots()
sns.stripplot(data=DFval, y= 'UnderSampled_AUC', x='TimeGroup', hue='Models', ax=ax)
plt.xticks(rotation=45)
ax.set_title('Week1-4 Model Validation Set Comparions')
sns.move_legend(ax, "lower center", bbox_to_anchor=(.5, 0.5), ncol=3, title='Model', frameon=True)
plt.show()

fig.savefig('Overall_Model_Comparison_Oversampled_rocAUC_ValidationSet.png', bbox_inches='tight', dpi=300)

# %% [markdown]
# ### Balanced Accuarcy

# %%
############################################### WEEK 1 #########################################
from imblearn.under_sampling import RandomUnderSampler

# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html



df = pd.read_csv('ValidationSet.txt', sep='\t', index_col=0)
Week1 = df.loc[(df['TimeGroup']=='Week1')|(df['TimeGroup']=='Healthy')]

yVAL = Week1.Status.copy()
yVAL.replace('Melioid', 1, inplace=True)
yVAL.replace('Negative', 0, inplace=True)

XVAL = Week1.iloc[:,4:].copy()
XVAL = pd.get_dummies(XVAL)

RAND=np.random.RandomState(4)
############ MODELS

enet = LogisticRegression(penalty = 'elasticnet', C=0.0021544346900318843, l1_ratio=0.3666666666666667, solver = 'saga', max_iter=int(1e6)).fit(Xunder, Yunder)
W1Enet = balanced_accuracy_score(yVAL, enet.predict(XVAL))

LR = LogisticRegression(penalty = 'l1', C=0.004641588833612777, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W1LassoStrong = balanced_accuracy_score(yVAL, LR.predict(XVAL))

LR = LogisticRegression(penalty = 'l1', C=1000, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W1LassoWeak = balanced_accuracy_score(yVAL, LR.predict(XVAL))

LR = LogisticRegression(penalty = 'l1', C=0.004641588833612777, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W1RidgeStrong = balanced_accuracy_score(yVAL, LR.predict(XVAL))

LR = LogisticRegression(penalty = 'l1', C=1000, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W1LRidgeWeak = balanced_accuracy_score(yVAL, LR.predict(XVAL))

xgb =  XGBClassifier(objective='binary:logistic', eval_metric='logloss', random_state=RAND,colsample_bytree=0.05, learning_rate=0.001, max_depth=3, n_estimators=25, subsample=0.2).fit(Xunder,Yunder)
W1XGB = balanced_accuracy_score(yVAL, xgb.predict(XVAL))


############################################### WEEK 2 #########################################

enet = LogisticRegression(penalty = 'elasticnet', C=0.0021544346900318843, l1_ratio=0.6333333333333333, solver = 'saga', max_iter=int(1e6)).fit(Xunder, Yunder)
W2Enet = balanced_accuracy_score(yVAL, enet.predict(XVAL))

LR = LogisticRegression(penalty = 'l1', C=0.004641588833612777, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W2LassoStrong = balanced_accuracy_score(yVAL, LR.predict(XVAL))

LR = LogisticRegression(penalty = 'l1', C=1000, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W2LassoWeak = balanced_accuracy_score(yVAL, LR.predict(XVAL))

LR = LogisticRegression(penalty = 'l1', C=0.004641588833612777, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W2RidgeStrong = balanced_accuracy_score(yVAL, LR.predict(XVAL))

LR = LogisticRegression(penalty = 'l1', C=1000, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W2LRidgeWeak = balanced_accuracy_score(yVAL, LR.predict(XVAL))

xgb =  XGBClassifier(objective='binary:logistic', eval_metric='logloss', random_state=RAND,colsample_bytree=0.05, learning_rate=0.001, max_depth=3, n_estimators=50, subsample=0.55).fit(Xunder,Yunder)
W2XGB = balanced_accuracy_score(yVAL, xgb.predict(XVAL))


############################################### WEEK 3 #########################################

enet = LogisticRegression(penalty = 'elasticnet', C=0.0021544346900318843, l1_ratio=0.6333333333333333, solver = 'saga', max_iter=int(1e6)).fit(Xunder, Yunder)
W3Enet = balanced_accuracy_score(yVAL, enet.predict(XVAL))


LR = LogisticRegression(penalty = 'l1', C=0.004641588833612777, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W3LassoStrong = balanced_accuracy_score(yVAL, LR.predict(XVAL))

LR = LogisticRegression(penalty = 'l1', C=1000, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W3LassoWeak = balanced_accuracy_score(yVAL, LR.predict(XVAL))

LR = LogisticRegression(penalty = 'l1', C=0.004641588833612777, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W3RidgeStrong = balanced_accuracy_score(yVAL, LR.predict(XVAL))

LR = LogisticRegression(penalty = 'l1', C=1000, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W3LRidgeWeak = balanced_accuracy_score(yVAL, LR.predict(XVAL))

xgb =  XGBClassifier(objective='binary:logistic', eval_metric='logloss', random_state=RAND,colsample_bytree=0.05, learning_rate=0.001, max_depth=3, n_estimators=50, subsample=0.55).fit(Xunder,Yunder)
W3XGB = balanced_accuracy_score(yVAL, xgb.predict(XVAL))


############################################### WEEK 4 #########################################

enet = LogisticRegression(penalty = 'elasticnet', C=0.0021544346900318843, l1_ratio=0.6333333333333333, solver = 'saga', max_iter=int(1e6)).fit(Xunder, Yunder)
W4Enet = balanced_accuracy_score(yVAL, enet.predict(XVAL))

LR = LogisticRegression(penalty = 'l1', C=0.004641588833612777, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W4LassoStrong = balanced_accuracy_score(yVAL, LR.predict(XVAL))

LR = LogisticRegression(penalty = 'l1', C=1000, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W4LassoWeak = balanced_accuracy_score(yVAL, LR.predict(XVAL))

LR = LogisticRegression(penalty = 'l1', C=0.004641588833612777, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W4RidgeStrong = balanced_accuracy_score(yVAL, LR.predict(XVAL))

LR = LogisticRegression(penalty = 'l1', C=1000, solver = 'saga', max_iter=int(1e6)).fit(Xunder,Yunder)
W4LRidgeWeak = balanced_accuracy_score(yVAL, LR.predict(XVAL))

xgb =  XGBClassifier(objective='binary:logistic', eval_metric='logloss', random_state=RAND,colsample_bytree=0.05, learning_rate=0.001, max_depth=3, n_estimators=50, subsample=0.55).fit(Xunder,Yunder)
W4XGB = balanced_accuracy_score(yVAL, xgb.predict(XVAL))

# %%
Vals = [W1Enet, W1LassoStrong, W1LassoWeak, W1RidgeStrong, W1LRidgeWeak, W1XGB, W2Enet, W2LassoStrong, W2LassoWeak, W2RidgeStrong, W2LRidgeWeak, W2XGB, W3Enet, W3LassoStrong, W3LassoWeak, W3RidgeStrong, W3LRidgeWeak, W3XGB, W4Enet, W4LassoStrong, W4LassoWeak, W4RidgeStrong, W4LRidgeWeak, W4XGB]
Mods = ['Enet', 'LassoStrong', 'LassoWeak', 'RidgeStrong', 'LRidgeWeak', 'XGB', 'Enet', 'LassoStrong', 'LassoWeak', 'RidgeStrong', 'LRidgeWeak', 'XGB', 'Enet', 'LassoStrong', 'LassoWeak', 'RidgeStrong', 'LRidgeWeak', 'XGB', 'Enet', 'LassoStrong', 'LassoWeak', 'RidgeStrong', 'LRidgeWeak', 'XGB']
Times = ['W1', 'W1', 'W1', 'W1', 'W1', 'W1', 'W2', 'W2', 'W2', 'W2', 'W2', 'W2', 'W3', 'W3', 'W3', 'W3', 'W3', 'W3', 'W4', 'W4', 'W4', 'W4', 'W4', 'W4']

DFBval = pd.DataFrame({'Balanced_Accuracy':Vals, 'Models':Mods, 'TimeGroup':Times})


fig, ax = plt.subplots()
sns.lineplot(data=DFBval, y= 'Balanced_Accuracy', hue='Models',x='TimeGroup', markers=True, dashes=True, ax=ax) #color='Models'
plt.xticks(rotation=45)
ax.set_title('Week1-4 Model Validation Set Comparions')
sns.move_legend(ax, "lower center", bbox_to_anchor=(.5, -0.35), ncol=3, title='Model', frameon=True)
plt.show()

# fig.savefig('Overall_Model_Comparison_Oversampled_BalancedAccuracy_ValidationSet.png', bbox_inches='tight', dpi=300)

# %%
fig, ax = plt.subplots(nrows=3, sharex=True, sharey=False)


sns.boxplot(data=BEST, y= 'mean_test_score', x='TimeGroup', hue='Model', ax=ax[0])
# plt.xticks(rotation=45)
# ax.set_title('Week1-4 Model Comparions')
ax[0].get_legend().remove()
ax[0].set(xlabel=None)

sns.stripplot(data=DFval, y= 'UnderSampled_AUC', x='TimeGroup', hue='Models', ax=ax[1])
# plt.xticks(rotation=45)
# ax.set_title('Week1-4 Model Validation Set Comparions')
sns.move_legend(ax[1], "lower center", bbox_to_anchor=(.5, 0.5), ncol=3, title='Model', frameon=True)
ax[1].get_legend().remove()
ax[1].set(xlabel=None)

sns.stripplot(data=DFBval, y= 'Balanced_Accuracy', hue='Models', hue_order=['LassoWeak', 'LassoStrong', 'RidgeWeak', 'RidgeStrong', 'ElasticNet', 'XGB'], x='TimeGroup', ax=ax[2]) #color='Models'
plt.xticks(rotation=45)
# ax.set_title('Week1-4 Model Validation Set Comparions')
sns.move_legend(ax[2], "lower center", bbox_to_anchor=(.5, -1.25), ncol=3, title='Model', frameon=True)
plt.show()

# %%
grid = plt.GridSpec(3,2)
ax1 = plt.subplot(grid[0, 0])
ax2 = plt.subplot(grid[0, 1:])
ax3 = plt.subplot(grid[1, :2])



# fig, ax = plt.subplots(nrows=3, sharex=True, sharey=False)


sns.boxplot(data=BEST, y= 'mean_test_score', x='TimeGroup', hue='Model', ax=ax3)
# plt.xticks(rotation=45)
# ax.set_title('Week1-4 Model Comparions')
# ax3.get_legend().remove()
# ax3.set(xlabel=None)
ax3.set_ylabel('Oversampled \nROC_AUC score')

sns.stripplot(data=DFval, y= 'UnderSampled_AUC', x='TimeGroup', hue='Models', ax=ax2)
# plt.xticks(rotation=45)
# # ax.set_title('Week1-4 Model Validation Set Comparions')
# sns.move_legend(ax3, "lower center", bbox_to_anchor=(.5, -1.1), ncol=3, title='Model', frameon=True)
ax2.get_legend().remove()
ax2.set(xlabel=None)
ax2.set_ylabel('Undersampled\nROC_AUC score')

sns.stripplot(data=DFBval, y= 'Balanced_Accuracy', hue='Models', hue_order=['LassoWeak', 'LassoStrong', 'RidgeWeak', 'RidgeStrong', 'ElasticNet', 'XGB'], x='TimeGroup', ax=ax1) #color='Models'
plt.xticks(rotation=45)
ax1.get_legend().remove()
ax1.set_ylabel('BA score')
sns.move_legend(ax3, "lower center", bbox_to_anchor=(.5, -1.25), ncol=3, title='Model', frameon=True)
plt.show()

# %% [markdown]
# ## Feauture Coefficients
# ### Week 1

# %%
parentdir = os.getcwd()

X = pd.read_csv('../OverSampled/W1_predictor.txt', sep='\t', index_col=0)
Y = pd.read_csv('../OverSampled/W1_response.txt', sep='\t', index_col=0).squeeze()
enet = LogisticRegression(penalty = 'elasticnet', C=0.0021544346900318843, l1_ratio=0.6333333333333333, solver = 'saga', max_iter=int(1e6)).fit(X,Y)

coefsDF = pd.DataFrame(np.transpose(enet.coef_), X.columns, columns=['Week1_Coefficients']).sort_values('Week1_Coefficients', ascending=False)

# %% [markdown]
# ### Week2

# %%
X = pd.read_csv('../OverSampled/W2_predictor.txt', sep='\t', index_col=0)
Y = pd.read_csv('../OverSampled/W2_response.txt', sep='\t', index_col=0).squeeze()
enet = LogisticRegression(penalty = 'elasticnet', C=0.0021544346900318843, l1_ratio=0.6333333333333333, solver = 'saga', max_iter=int(1e6)).fit(X,Y)

coefsDF2 = pd.DataFrame(np.transpose(enet.coef_), X.columns, columns=['Week2_Coefficients']).sort_values('Week2_Coefficients', ascending=False)

# %% [markdown]
# ### Week3

# %%
X = pd.read_csv('../OverSampled/W3_predictor.txt', sep='\t', index_col=0)
Y = pd.read_csv('../OverSampled/W3_response.txt', sep='\t', index_col=0).squeeze()
enet = LogisticRegression(penalty = 'elasticnet', C=0.0021544346900318843, l1_ratio=0.6333333333333333, solver = 'saga', max_iter=int(1e6)).fit(X,Y)

coefsDF3 = pd.DataFrame(np.transpose(enet.coef_), X.columns, columns=['Week3_Coefficients']).sort_values('Week3_Coefficients', ascending=False)

# %% [markdown]
# ### Week 4

# %%
X = pd.read_csv('../OverSampled/W4_predictor.txt', sep='\t', index_col=0)
Y = pd.read_csv('../OverSampled/W4_response.txt', sep='\t', index_col=0).squeeze()
enet = LogisticRegression(penalty = 'elasticnet', C=0.0021544346900318843, l1_ratio=0.6333333333333333, solver = 'saga', max_iter=int(1e6)).fit(X,Y)

coefsDF4 = pd.DataFrame(np.transpose(enet.coef_), X.columns, columns=['Week4_Coefficients']).sort_values('Week4_Coefficients', ascending=False)

# %%
TESTING = pd.concat([coefsDF,coefsDF2, coefsDF3, coefsDF4 ], axis=1)
TESTING.to_excel('BestENETcoefs.xlsx')
