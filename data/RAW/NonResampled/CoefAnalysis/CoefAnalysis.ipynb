# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ### IgG Coefs

# %%
enet_igg_w1 = pd.read_excel('../IgG/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_Enet').assign(method='Enet').rename(columns={'Week1_Coefficients':'Coeff'})
LRstr_igg_w1 = pd.read_excel('../IgG/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_LassoStrong').assign(method='LRstrong').rename(columns={'Week1_Coefficients':'Coeff'})
LRwk_igg_w1 = pd.read_excel('../IgG/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_LassoWeak').assign(method='LRweak').rename(columns={'Week1_Coefficients':'Coeff'})
Rstr_igg_w1 = pd.read_excel('../IgG/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week1_Coefficients':'Coeff'})
Rwk_igg_w1 = pd.read_excel('../IgG/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week1_Coefficients':'Coeff'})

week1 = pd.concat([enet_igg_w1, LRstr_igg_w1, LRwk_igg_w1, Rstr_igg_w1, Rwk_igg_w1])
week1['TimeGroup'] ='Week1'

enet_igg_w2 = pd.read_excel('../IgG/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_Enet').assign(method='Enet').rename(columns={'Week2_Coefficients':'Coeff'})
LRstr_igg_w2 = pd.read_excel('../IgG/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_LassoStrong').assign(method='LRstrong').rename(columns={'Week2_Coefficients':'Coeff'})
LRwk_igg_w2 = pd.read_excel('../IgG/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_LassoWeak').assign(method='LRweak').rename(columns={'Week2_Coefficients':'Coeff'})
Rstr_igg_w2 = pd.read_excel('../IgG/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week2_Coefficients':'Coeff'})
Rwk_igg_w2 = pd.read_excel('../IgG/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week2_Coefficients':'Coeff'})

week2 = pd.concat([enet_igg_w2, LRstr_igg_w2, LRwk_igg_w2, Rstr_igg_w2, Rwk_igg_w2])
week2['TimeGroup'] ='Week2'


enet_igg_w3 = pd.read_excel('../IgG/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_Enet').assign(method='Enet').rename(columns={'Week3_Coefficients':'Coeff'})
LRstr_igg_w3 = pd.read_excel('../IgG/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_LassoStrong').assign(method='LRstrong').rename(columns={'Week3_Coefficients':'Coeff'})
LRwk_igg_w3 = pd.read_excel('../IgG/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_LassoWeak').assign(method='LRweak').rename(columns={'Week3_Coefficients':'Coeff'})
Rstr_igg_w3 = pd.read_excel('../IgG/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week3_Coefficients':'Coeff'})
Rwk_igg_w3 = pd.read_excel('../IgG/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week3_Coefficients':'Coeff'})

week3 = pd.concat([enet_igg_w3, LRstr_igg_w3, LRwk_igg_w3, Rstr_igg_w3, Rwk_igg_w3])
week3['TimeGroup'] ='Week3'


enet_igg_w4 = pd.read_excel('../IgG/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_Enet').assign(method='Enet').rename(columns={'Week4_Coefficients':'Coeff'})
LRstr_igg_w4 = pd.read_excel('../IgG/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_LassoStrong').assign(method='LRstrong').rename(columns={'Week4_Coefficients':'Coeff'})
LRwk_igg_w4 = pd.read_excel('../IgG/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_LassoWeak').assign(method='LRweak').rename(columns={'Week4_Coefficients':'Coeff'})
Rstr_igg_w4 = pd.read_excel('../IgG/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week4_Coefficients':'Coeff'})
Rwk_igg_w4 = pd.read_excel('../IgG/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week4_Coefficients':'Coeff'})

week4 = pd.concat([enet_igg_w4, LRstr_igg_w4, LRwk_igg_w4, Rstr_igg_w4, Rwk_igg_w4])
week4['TimeGroup'] ='Week4'

IgG = pd.concat([week1, week2, week3, week4])
IgG['Assay'] = 'IgG'

# %% [markdown]
# ## IgM

# %%
enet_igg_w1 = pd.read_excel('../IgM/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_Enet').assign(method='Enet').rename(columns={'Week1_Coefficients':'Coeff'})
LRstr_igg_w1 = pd.read_excel('../IgM/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_LassoStrong').assign(method='LRstrong').rename(columns={'Week1_Coefficients':'Coeff'})
LRwk_igg_w1 = pd.read_excel('../IgM/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_LassoWeak').assign(method='LRweak').rename(columns={'Week1_Coefficients':'Coeff'})
Rstr_igg_w1 = pd.read_excel('../IgM/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week1_Coefficients':'Coeff'})
Rwk_igg_w1 = pd.read_excel('../IgM/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week1_Coefficients':'Coeff'})

week1 = pd.concat([enet_igg_w1, LRstr_igg_w1, LRwk_igg_w1, Rstr_igg_w1, Rwk_igg_w1])
week1['TimeGroup'] ='Week1'

enet_igg_w2 = pd.read_excel('../IgM/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_Enet').assign(method='Enet').rename(columns={'Week2_Coefficients':'Coeff'})
LRstr_igg_w2 = pd.read_excel('../IgM/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_LassoStrong').assign(method='LRstrong').rename(columns={'Week2_Coefficients':'Coeff'})
LRwk_igg_w2 = pd.read_excel('../IgM/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_LassoWeak').assign(method='LRweak').rename(columns={'Week2_Coefficients':'Coeff'})
Rstr_igg_w2 = pd.read_excel('../IgM/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week2_Coefficients':'Coeff'})
Rwk_igg_w2 = pd.read_excel('../IgM/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week2_Coefficients':'Coeff'})

week2 = pd.concat([enet_igg_w2, LRstr_igg_w2, LRwk_igg_w2, Rstr_igg_w2, Rwk_igg_w2])
week2['TimeGroup'] ='Week2'


enet_igg_w3 = pd.read_excel('../IgM/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_Enet').assign(method='Enet').rename(columns={'Week3_Coefficients':'Coeff'})
LRstr_igg_w3 = pd.read_excel('../IgM/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_LassoStrong').assign(method='LRstrong').rename(columns={'Week3_Coefficients':'Coeff'})
LRwk_igg_w3 = pd.read_excel('../IgM/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_LassoWeak').assign(method='LRweak').rename(columns={'Week3_Coefficients':'Coeff'})
Rstr_igg_w3 = pd.read_excel('../IgM/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week3_Coefficients':'Coeff'})
Rwk_igg_w3 = pd.read_excel('../IgM/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week3_Coefficients':'Coeff'})

week3 = pd.concat([enet_igg_w3, LRstr_igg_w3, LRwk_igg_w3, Rstr_igg_w3, Rwk_igg_w3])
week3['TimeGroup'] ='Week3'


enet_igg_w4 = pd.read_excel('../IgM/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_Enet').assign(method='Enet').rename(columns={'Week4_Coefficients':'Coeff'})
LRstr_igg_w4 = pd.read_excel('../IgM/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_LassoStrong').assign(method='LRstrong').rename(columns={'Week4_Coefficients':'Coeff'})
LRwk_igg_w4 = pd.read_excel('../IgM/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_LassoWeak').assign(method='LRweak').rename(columns={'Week4_Coefficients':'Coeff'})
Rstr_igg_w4 = pd.read_excel('../IgM/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week4_Coefficients':'Coeff'})
Rwk_igg_w4 = pd.read_excel('../IgM/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week4_Coefficients':'Coeff'})

week4 = pd.concat([enet_igg_w4, LRstr_igg_w4, LRwk_igg_w4, Rstr_igg_w4, Rwk_igg_w4])
week4['TimeGroup'] ='Week4'

IgM = pd.concat([week1, week2, week3, week4])
IgM['Assay'] = 'IgM'

# %% [markdown]
# ## IgGM

# %%
enet_igg_w1 = pd.read_excel('../IgGM/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_Enet').assign(method='Enet').rename(columns={'Week1_Coefficients':'Coeff'})
LRstr_igg_w1 = pd.read_excel('../IgGM/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_LassoStrong').assign(method='LRstrong').rename(columns={'Week1_Coefficients':'Coeff'})
LRwk_igg_w1 = pd.read_excel('../IgGM/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_LassoWeak').assign(method='LRweak').rename(columns={'Week1_Coefficients':'Coeff'})
Rstr_igg_w1 = pd.read_excel('../IgGM/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week1_Coefficients':'Coeff'})
Rwk_igg_w1 = pd.read_excel('../IgGM/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week1_Coefficients':'Coeff'})

week1 = pd.concat([enet_igg_w1, LRstr_igg_w1, LRwk_igg_w1, Rstr_igg_w1, Rwk_igg_w1])
week1['TimeGroup'] ='Week1'

enet_igg_w2 = pd.read_excel('../IgGM/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_Enet').assign(method='Enet').rename(columns={'Week2_Coefficients':'Coeff'})
LRstr_igg_w2 = pd.read_excel('../IgGM/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_LassoStrong').assign(method='LRstrong').rename(columns={'Week2_Coefficients':'Coeff'})
LRwk_igg_w2 = pd.read_excel('../IgGM/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_LassoWeak').assign(method='LRweak').rename(columns={'Week2_Coefficients':'Coeff'})
Rstr_igg_w2 = pd.read_excel('../IgGM/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week2_Coefficients':'Coeff'})
Rwk_igg_w2 = pd.read_excel('../IgGM/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week2_Coefficients':'Coeff'})

week2 = pd.concat([enet_igg_w2, LRstr_igg_w2, LRwk_igg_w2, Rstr_igg_w2, Rwk_igg_w2])
week2['TimeGroup'] ='Week2'


enet_igg_w3 = pd.read_excel('../IgGM/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_Enet').assign(method='Enet').rename(columns={'Week3_Coefficients':'Coeff'})
LRstr_igg_w3 = pd.read_excel('../IgGM/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_LassoStrong').assign(method='LRstrong').rename(columns={'Week3_Coefficients':'Coeff'})
LRwk_igg_w3 = pd.read_excel('../IgGM/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_LassoWeak').assign(method='LRweak').rename(columns={'Week3_Coefficients':'Coeff'})
Rstr_igg_w3 = pd.read_excel('../IgGM/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week3_Coefficients':'Coeff'})
Rwk_igg_w3 = pd.read_excel('../IgGM/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week3_Coefficients':'Coeff'})

week3 = pd.concat([enet_igg_w3, LRstr_igg_w3, LRwk_igg_w3, Rstr_igg_w3, Rwk_igg_w3])
week3['TimeGroup'] ='Week3'


enet_igg_w4 = pd.read_excel('../IgGM/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_Enet').assign(method='Enet').rename(columns={'Week4_Coefficients':'Coeff'})
LRstr_igg_w4 = pd.read_excel('../IgGM/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_LassoStrong').assign(method='LRstrong').rename(columns={'Week4_Coefficients':'Coeff'})
LRwk_igg_w4 = pd.read_excel('../IgGM/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_LassoWeak').assign(method='LRweak').rename(columns={'Week4_Coefficients':'Coeff'})
Rstr_igg_w4 = pd.read_excel('../IgGM/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week4_Coefficients':'Coeff'})
Rwk_igg_w4 = pd.read_excel('../IgGM/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week4_Coefficients':'Coeff'})

week4 = pd.concat([enet_igg_w4, LRstr_igg_w4, LRwk_igg_w4, Rstr_igg_w4, Rwk_igg_w4])
week4['TimeGroup'] ='Week4'

IgGM = pd.concat([week1, week2, week3, week4])
IgGM['Assay'] = 'IgGM'

# %%
DF = pd.concat([IgG, IgM, IgGM])
sns.set_theme(style = "whitegrid")#", font_scale= 0.5
# fig, ax=plt.subplots(figsize=(20,10))
g= sns.catplot(data=DF, x='Unnamed: 0', y='Coeff', col='TimeGroup', hue='method', kind='box', col_wrap=2)
g.set_xticklabels(rotation=1)
# ax.set_xticklabels(ax.get_xticklabels(),rotation=90, minor=False);
# g.set_xticklabels(g.get_xticklabels(), rotation=30)
for ax in g.axes:
    ax.set_xticklabels(DF['Unnamed: 0'].unique(), rotation=90)
    ax.tick_params(labelbottom=True)
plt.subplots_adjust(bottom=0.1, left=0.06, hspace=0.2)
plt.show()

# %%
[DF['Unnamed: 0'].unique()]
# Out:
# [array(['BPSS1769_NADH', 'BPSL1201_IMPS', 'BPSL2522_OmpA', 'BPSL1404_ClpX',
#         'LPSB', 'BPSS0135', 'BPSS0477_GroEL2', 'BPSS1850', 'BPSL3222_rpIL',
#         'CPS', 'BPSS1652', 'BPSS0476_GroS', 'BPSL3396_AtpD',
#         'BPSL2697_GroEL', 'LPSA', 'BPSL1743_Arg', 'BPSL2827_DNAK',
#         'BPSL2096_AhpC', 'BPSS0530', 'BPSS1498_HCP1.B'], dtype=object)]
