# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ### IgG Coefs

# %%
enet_igg_w1 = pd.read_excel('../IgG/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_Enet').assign(method='Enet').rename(columns={'Week1_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRstr_igg_w1 = pd.read_excel('../IgG/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_LassoStrong').assign(method='LRstrong').rename(columns={'Week1_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRwk_igg_w1 = pd.read_excel('../IgG/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_LassoWeak').assign(method='LRweak').rename(columns={'Week1_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rstr_igg_w1 = pd.read_excel('../IgG/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week1_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rwk_igg_w1 = pd.read_excel('../IgG/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week1_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)

week1 = pd.concat([enet_igg_w1, LRstr_igg_w1, LRwk_igg_w1, Rstr_igg_w1, Rwk_igg_w1])
week1['TimeGroup'] ='Week1'

enet_igg_w2 = pd.read_excel('../IgG/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_Enet').assign(method='Enet').rename(columns={'Week2_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRstr_igg_w2 = pd.read_excel('../IgG/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_LassoStrong').assign(method='LRstrong').rename(columns={'Week2_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRwk_igg_w2 = pd.read_excel('../IgG/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_LassoWeak').assign(method='LRweak').rename(columns={'Week2_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rstr_igg_w2 = pd.read_excel('../IgG/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week2_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rwk_igg_w2 = pd.read_excel('../IgG/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week2_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)

week2 = pd.concat([enet_igg_w2, LRstr_igg_w2, LRwk_igg_w2, Rstr_igg_w2, Rwk_igg_w2])
week2['TimeGroup'] ='Week2'


enet_igg_w3 = pd.read_excel('../IgG/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_Enet').assign(method='Enet').rename(columns={'Week3_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRstr_igg_w3 = pd.read_excel('../IgG/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_LassoStrong').assign(method='LRstrong').rename(columns={'Week3_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRwk_igg_w3 = pd.read_excel('../IgG/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_LassoWeak').assign(method='LRweak').rename(columns={'Week3_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rstr_igg_w3 = pd.read_excel('../IgG/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week3_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rwk_igg_w3 = pd.read_excel('../IgG/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week3_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)

week3 = pd.concat([enet_igg_w3, LRstr_igg_w3, LRwk_igg_w3, Rstr_igg_w3, Rwk_igg_w3])
week3['TimeGroup'] ='Week3'


enet_igg_w4 = pd.read_excel('../IgG/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_Enet').assign(method='Enet').rename(columns={'Week4_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRstr_igg_w4 = pd.read_excel('../IgG/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_LassoStrong').assign(method='LRstrong').rename(columns={'Week4_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRwk_igg_w4 = pd.read_excel('../IgG/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_LassoWeak').assign(method='LRweak').rename(columns={'Week4_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rstr_igg_w4 = pd.read_excel('../IgG/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week4_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rwk_igg_w4 = pd.read_excel('../IgG/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week4_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)

week4 = pd.concat([enet_igg_w4, LRstr_igg_w4, LRwk_igg_w4, Rstr_igg_w4, Rwk_igg_w4])
week4['TimeGroup'] ='Week4'

IgG = pd.concat([week1, week2, week3, week4])
IgG['Assay'] = 'IgG'

# %% [markdown]
# ## IgM

# %%
enet_igg_w1 = pd.read_excel('../IgM/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_Enet').assign(method='Enet').rename(columns={'Week1_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRstr_igg_w1 = pd.read_excel('../IgM/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_LassoStrong').assign(method='LRstrong').rename(columns={'Week1_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRwk_igg_w1 = pd.read_excel('../IgM/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_LassoWeak').assign(method='LRweak').rename(columns={'Week1_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rstr_igg_w1 = pd.read_excel('../IgM/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week1_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rwk_igg_w1 = pd.read_excel('../IgM/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week1_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)

week1 = pd.concat([enet_igg_w1, LRstr_igg_w1, LRwk_igg_w1, Rstr_igg_w1, Rwk_igg_w1])
week1['TimeGroup'] ='Week1'

enet_igg_w2 = pd.read_excel('../IgM/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_Enet').assign(method='Enet').rename(columns={'Week2_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRstr_igg_w2 = pd.read_excel('../IgM/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_LassoStrong').assign(method='LRstrong').rename(columns={'Week2_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRwk_igg_w2 = pd.read_excel('../IgM/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_LassoWeak').assign(method='LRweak').rename(columns={'Week2_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rstr_igg_w2 = pd.read_excel('../IgM/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week2_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rwk_igg_w2 = pd.read_excel('../IgM/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week2_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)

week2 = pd.concat([enet_igg_w2, LRstr_igg_w2, LRwk_igg_w2, Rstr_igg_w2, Rwk_igg_w2])
week2['TimeGroup'] ='Week2'


enet_igg_w3 = pd.read_excel('../IgM/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_Enet').assign(method='Enet').rename(columns={'Week3_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRstr_igg_w3 = pd.read_excel('../IgM/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_LassoStrong').assign(method='LRstrong').rename(columns={'Week3_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRwk_igg_w3 = pd.read_excel('../IgM/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_LassoWeak').assign(method='LRweak').rename(columns={'Week3_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rstr_igg_w3 = pd.read_excel('../IgM/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week3_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rwk_igg_w3 = pd.read_excel('../IgM/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week3_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)

week3 = pd.concat([enet_igg_w3, LRstr_igg_w3, LRwk_igg_w3, Rstr_igg_w3, Rwk_igg_w3])
week3['TimeGroup'] ='Week3'


enet_igg_w4 = pd.read_excel('../IgM/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_Enet').assign(method='Enet').rename(columns={'Week4_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRstr_igg_w4 = pd.read_excel('../IgM/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_LassoStrong').assign(method='LRstrong').rename(columns={'Week4_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRwk_igg_w4 = pd.read_excel('../IgM/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_LassoWeak').assign(method='LRweak').rename(columns={'Week4_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rstr_igg_w4 = pd.read_excel('../IgM/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week4_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rwk_igg_w4 = pd.read_excel('../IgM/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week4_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)

week4 = pd.concat([enet_igg_w4, LRstr_igg_w4, LRwk_igg_w4, Rstr_igg_w4, Rwk_igg_w4])
week4['TimeGroup'] ='Week4'

IgM = pd.concat([week1, week2, week3, week4])
IgM['Assay'] = 'IgM'

# %% [markdown]
# ## IgGM

# %%
enet_igg_w1 = pd.read_excel('../IgGM/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_Enet').assign(method='Enet').rename(columns={'Week1_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRstr_igg_w1 = pd.read_excel('../IgGM/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_LassoStrong').assign(method='LRstrong').rename(columns={'Week1_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRwk_igg_w1 = pd.read_excel('../IgGM/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_LassoWeak').assign(method='LRweak').rename(columns={'Week1_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rstr_igg_w1 = pd.read_excel('../IgGM/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week1_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rwk_igg_w1 = pd.read_excel('../IgGM/Results/Tables/Week1_Coeffs.xlsx', sheet_name='Week1_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week1_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)

week1 = pd.concat([enet_igg_w1, LRstr_igg_w1, LRwk_igg_w1, Rstr_igg_w1, Rwk_igg_w1])
week1['TimeGroup'] ='Week1'

enet_igg_w2 = pd.read_excel('../IgGM/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_Enet').assign(method='Enet').rename(columns={'Week2_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRstr_igg_w2 = pd.read_excel('../IgGM/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_LassoStrong').assign(method='LRstrong').rename(columns={'Week2_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRwk_igg_w2 = pd.read_excel('../IgGM/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_LassoWeak').assign(method='LRweak').rename(columns={'Week2_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rstr_igg_w2 = pd.read_excel('../IgGM/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week2_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rwk_igg_w2 = pd.read_excel('../IgGM/Results/Tables/Week2_Coeffs.xlsx', sheet_name='Week2_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week2_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)

week2 = pd.concat([enet_igg_w2, LRstr_igg_w2, LRwk_igg_w2, Rstr_igg_w2, Rwk_igg_w2])
week2['TimeGroup'] ='Week2'


enet_igg_w3 = pd.read_excel('../IgGM/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_Enet').assign(method='Enet').rename(columns={'Week3_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRstr_igg_w3 = pd.read_excel('../IgGM/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_LassoStrong').assign(method='LRstrong').rename(columns={'Week3_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRwk_igg_w3 = pd.read_excel('../IgGM/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_LassoWeak').assign(method='LRweak').rename(columns={'Week3_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rstr_igg_w3 = pd.read_excel('../IgGM/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week3_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rwk_igg_w3 = pd.read_excel('../IgGM/Results/Tables/Week3_Coeffs.xlsx', sheet_name='Week3_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week3_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)

week3 = pd.concat([enet_igg_w3, LRstr_igg_w3, LRwk_igg_w3, Rstr_igg_w3, Rwk_igg_w3])
week3['TimeGroup'] ='Week3'


enet_igg_w4 = pd.read_excel('../IgGM/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_Enet').assign(method='Enet').rename(columns={'Week4_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRstr_igg_w4 = pd.read_excel('../IgGM/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_LassoStrong').assign(method='LRstrong').rename(columns={'Week4_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
LRwk_igg_w4 = pd.read_excel('../IgGM/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_LassoWeak').assign(method='LRweak').rename(columns={'Week4_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rstr_igg_w4 = pd.read_excel('../IgGM/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_RidgeStrong').assign(method='Ridgestrong').rename(columns={'Week4_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)
Rwk_igg_w4 = pd.read_excel('../IgGM/Results/Tables/Week4_Coeffs.xlsx', sheet_name='Week4_RidgeWeak').assign(method='Ridgeweak').rename(columns={'Week4_Coefficients':'Coeff'}).sort_values('Coeff', ascending=False)

week4 = pd.concat([enet_igg_w4, LRstr_igg_w4, LRwk_igg_w4, Rstr_igg_w4, Rwk_igg_w4])
week4['TimeGroup'] ='Week4'

IgGM = pd.concat([week1, week2, week3, week4])
IgGM['Assay'] = 'IgGM'
DF = pd.concat([IgG, IgM, IgGM])

# %%
Enet = DF.loc[DF['method']=='Enet'].copy()
LRstrong = DF.loc[DF['method']=='LRstrong'].copy()
LRweak = DF.loc[DF['method']=='LRweak'].copy()
Ridgestrong = DF.loc[DF['method']=='Ridgestrong'].copy()
Ridgeweak = DF.loc[DF['method']=='Ridgeweak'].copy()
# DF.method.unique()

# %%
w1 = Enet.loc[Enet['TimeGroup']=='Week1'].copy()
w2 = Enet.loc[Enet['TimeGroup']=='Week2'].copy()
w3 = Enet.loc[Enet['TimeGroup']=='Week3'].copy()
w4 = Enet.loc[Enet['TimeGroup']=='Week4'].copy()

sns.set_theme(style = "darkgrid")
fig, ax = plt.subplots(nrows=2, ncols=2, sharey=True, sharex=True, figsize=(10,8))
sns.stripplot(data=w1, x='Unnamed: 0', y='Coeff',  hue='Assay', ax=ax[0,0])
sns.stripplot(data=w2, x='Unnamed: 0', y='Coeff',  hue='Assay',ax=ax[0,1])
sns.stripplot(data=w3, x='Unnamed: 0', y='Coeff',  hue='Assay',ax=ax[1,0])
sns.stripplot(data=w4, x='Unnamed: 0', y='Coeff',  hue='Assay',ax=ax[1,1])
ax[0,0].set(title='Week1', xlabel=None)
ax[0,1].set(title='Week2',xlabel=None)
ax[1,0].set(title='Week3',xlabel=None)
ax[1,1].set(title='Week4',xlabel=None)


# ax.set_xticklabels(ax.get_xticks(), rotation = 50)
ax[1,0].tick_params(axis='x',labelrotation=90)
ax[1,1].tick_params(axis='x', labelrotation=90)

ax[1,1].get_legend().remove()
ax[1,0].get_legend().remove()
ax[0,1].get_legend().remove()
ax[0,0].get_legend().remove()
# ax[0,0].legend(loc='upper center', bbox_to_anchor=(1.05, 1.05),ncol=3, fancybox=True, shadow=True)
fig.subplots_adjust(top=0.9, left=0.1, right=0.9, bottom=0.12)
ax.flatten()[-1].legend(loc='lower center', bbox_to_anchor=(0.5, -1), ncol=3)
# fig.legend(labels=['IgG', 'IgM', 'IgGM'], loc = (0.4, -0.1), ncol=3)
fig.suptitle("Immunologially Activated Antigens",fontsize=14)
fig.tight_layout()

# %%
w1 = LRstrong.loc[LRstrong['TimeGroup']=='Week1'].copy()
w2 = LRstrong.loc[LRstrong['TimeGroup']=='Week2'].copy()
w3 = LRstrong.loc[LRstrong['TimeGroup']=='Week3'].copy()
w4 = LRstrong.loc[LRstrong['TimeGroup']=='Week4'].copy()

sns.set_theme(style = "darkgrid")
fig, ax = plt.subplots(nrows=2, ncols=2, sharey=True, sharex=True, figsize=(9,5))
sns.stripplot(data=w1, x='Unnamed: 0', y='Coeff',  hue='Assay', jitter=False, ax=ax[0,0])
sns.stripplot(data=w2, x='Unnamed: 0', y='Coeff',  hue='Assay', jitter=False, ax=ax[0,1])
sns.stripplot(data=w3, x='Unnamed: 0', y='Coeff',  hue='Assay', jitter=False, ax=ax[1,0])
sns.stripplot(data=w4, x='Unnamed: 0', y='Coeff',  hue='Assay', jitter=False, ax=ax[1,1])
ax[0,0].set(title='Week1', xlabel=None)
ax[0,1].set(title='Week2',xlabel=None)
ax[1,0].set(title='Week3',xlabel=None)
ax[1,1].set(title='Week4',xlabel=None)


# ax.set_xticklabels(ax.get_xticks(), rotation = 50)
ax[1,0].tick_params(axis='x',labelrotation=90)
ax[1,1].tick_params(axis='x', labelrotation=90)

ax[1,1].get_legend().remove()
ax[1,0].get_legend().remove()
ax[0,1].get_legend().remove()
ax[0,0].get_legend().remove()
# ax[0,0].legend(loc='upper center', bbox_to_anchor=(1.05, 1.05),ncol=3, fancybox=True, shadow=True)
fig.subplots_adjust(top=0.9, left=0.1, right=0.9, bottom=0.12)
ax.flatten()[-1].legend(loc='lower center', bbox_to_anchor=(-0.17, -1.3), ncol=3)
# fig.legend(labels=['IgG', 'IgM', 'IgGM'], loc = (0.4, -0.1), ncol=3)
fig.suptitle("Immunologially Activated Antigens predicted by LassoStrong",fontsize=14)
fig.savefig('OverallModelCoeffs.png', dpi=300, bbox_inches='tight')
# fig.tight_layout()
