# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Week1
# * Class Imbalance
#         * df.Status.value_counts()
#             * Negative    1293
#             * Melioid       96
#     * Imbalanced roc_auc = 1293/(1293+96) =0.93
# ### Enet

# %%
if not os.path.isdir('Figures'):
    os.makedirs('Figures')
os.chdir('Figures')

Enet = pd.read_csv('../Week1_EnetBurkPx_GridSearch.txt', sep='\t', index_col=0)
Enet['params2'] = Enet['params'].astype(str)
fig, ax = plt.subplots()
sns.boxplot(data=Enet, y= 'mean_test_score', x='params2', ax=ax)
plt.xticks(rotation=90)
fig.savefig('W1_Enet.png', dpi=300, bbox_inches="tight", transparent=False)

# %%
{'C': 100, 'l1_ratio': 0.9}
# Out:
# {'C': 100, 'l1_ratio': 0.5}

# %% [markdown]
# ### Logit

# %%
LR = pd.read_csv('../Week1_LRBurkPx_GridSearch.txt', sep='\t', index_col=0)
LR['params2'] = LR['params'].astype(str)
fig, ax = plt.subplots()
sns.boxplot(data=LR, y= 'mean_test_score', x='params2', ax=ax)
plt.xticks(rotation=90)
fig.savefig('W1_LR.png', dpi=300, bbox_inches="tight", transparent=False)

# %%
### Strong penalization
{'C': 0.01291549665014884, 'penalty': 'l1'}
{'C': 0.01291549665014884, 'penalty': 'l2'}
### Weak penalization
{'C': 100, 'penalty': 'l1'}
{'C': 100, 'penalty': 'l2'}
# Out:
# {'C': 100, 'penalty': 'l2'}

# %% [markdown]
# ### XGB

# %%
XGB = pd.read_csv('../Week1_XGBBurkPx_GridSearch.txt', sep='\t', index_col=0)
XGB['params2'] = XGB['params'].astype(str)
fig, ax = plt.subplots()
sns.boxplot(data=XGB, y= 'mean_test_score', x='params2', ax=ax)
plt.xticks(rotation=90)
fig.savefig('W1_XGB.png', dpi=300, bbox_inches="tight", transparent=False)

# %%
### Hopefully not overfit:
{'colsample_bytree': 0.15000000000000002, 'learning_rate': 0.021544346900318832, 'max_depth': 11, 'n_estimators': 50, 'subsample': 0.7}
# Out:
# {'colsample_bytree': 0.15000000000000002,
#  'learning_rate': 0.021544346900318832,
#  'max_depth': 11,
#  'n_estimators': 50,
#  'subsample': 0.7}

# %% [markdown]
# ## Week2
# * Class Imbalance
#         * df.Status.value_counts()
#             * Negative    1293
#             * Melioid      162
#     * Imbalance roc_auc = 1293/(1293+162) = 0.889
# ### Enet

# %%
Enet = pd.read_csv('../Week2_EnetBurkPx_GridSearch.txt', sep='\t', index_col=0)
Enet['params2'] = Enet['params'].astype(str)
fig, ax = plt.subplots()
sns.boxplot(data=Enet, y= 'mean_test_score', x='params2', ax=ax)
plt.xticks(rotation=90)
fig.savefig('W2_Enet.png', dpi=300, bbox_inches="tight", transparent=False)

# %%
{'C': 100, 'l1_ratio': 0.9}

# %% [markdown]
# ### Logit

# %%
LR = pd.read_csv('../Week2_LRBurkPx_GridSearch.txt', sep='\t', index_col=0)
LR['params2'] = LR['params'].astype(str)
fig, ax = plt.subplots()
sns.boxplot(data=LR, y= 'mean_test_score', x='params2', ax=ax)
plt.xticks(rotation=90)
fig.savefig('W2_LR.png', dpi=300, bbox_inches="tight", transparent=False)

# %%
### Strong penalization
{'C': 0.01291549665014884, 'penalty': 'l1'}
{'C': 0.01291549665014884, 'penalty': 'l2'}
### Weak penalization
{'C': 100, 'penalty': 'l1'}
{'C': 100, 'penalty': 'l2'}

# %% [markdown]
# ### XGB

# %%
XGB = pd.read_csv('../Week2_XGBBurkPx_GridSearch.txt', sep='\t', index_col=0)
XGB['params2'] = XGB['params'].astype(str)
fig, ax = plt.subplots()
sns.boxplot(data=XGB, y= 'mean_test_score', x='params2', ax=ax)
plt.xticks(rotation=90)
fig.savefig('W2_XGB.png', dpi=300, bbox_inches="tight", transparent=False)

# %% [markdown]
# ## Week3
# * Class Imbalance
#         * df.Status.value_counts()
#             * Negative    1293
#             * Melioid      147
#     * Imbalance roc_auc = 1293/(1293+147) = 0.898
# ### Enet

# %%
Enet = pd.read_csv('../Week3_EnetBurkPx_GridSearch.txt', sep='\t', index_col=0)
Enet['params2'] = Enet['params'].astype(str)
fig, ax = plt.subplots()
sns.boxplot(data=Enet, y= 'mean_test_score', x='params2', ax=ax)
plt.xticks(rotation=90)
fig.savefig('W3_Enet.png', dpi=300, bbox_inches="tight", transparent=False)

# %% [markdown]
# ### Logit

# %%
LR = pd.read_csv('../Week3_LRBurkPx_GridSearch.txt', sep='\t', index_col=0)
LR['params2'] = LR['params'].astype(str)
fig, ax = plt.subplots()
sns.boxplot(data=LR, y= 'mean_test_score', x='params2', ax=ax)
plt.xticks(rotation=90)
fig.savefig('W3_LR.png', dpi=300, bbox_inches="tight", transparent=False)

# %%
### Strong penalization
{'C': 0.01291549665014884, 'penalty': 'l1'}
{'C': 0.01291549665014884, 'penalty': 'l2'}
### Weak penalization
{'C': 100, 'penalty': 'l1'}
{'C': 100, 'penalty': 'l2'}

# %% [markdown]
# ### XGB

# %%
XGB = pd.read_csv('../Week3_XGBBurkPx_GridSearch.txt', sep='\t', index_col=0)
XGB['params2'] = XGB['params'].astype(str)
fig, ax = plt.subplots()
sns.boxplot(data=XGB, y= 'mean_test_score', x='params2', ax=ax)
plt.xticks(rotation=90)
fig.savefig('W3_XGB.png', dpi=300, bbox_inches="tight", transparent=False)

# %% [markdown]
# ## Week4
# * Class Imbalance
#         * df.Status.value_counts()
#             * Negative    1293
#             * Melioid      867
#     * Imbalance roc_auc = 1293/(1293+867) = 0.598
# ### Enet

# %%
Enet = pd.read_csv('../Week4_EnetBurkPx_GridSearch.txt', sep='\t', index_col=0)
Enet['params2'] = Enet['params'].astype(str)
fig, ax = plt.subplots()
sns.boxplot(data=Enet, y= 'mean_test_score', x='params2', ax=ax)
plt.xticks(rotation=90)
fig.savefig('W4_Enet.png', dpi=300, bbox_inches="tight", transparent=False)

# %% [markdown]
# ### Logit

# %%
LR = pd.read_csv('../Week4_LRBurkPx_GridSearch.txt', sep='\t', index_col=0)
LR['params2'] = LR['params'].astype(str)
fig, ax = plt.subplots()
sns.boxplot(data=LR, y= 'mean_test_score', x='params2', ax=ax)
plt.xticks(rotation=90)
fig.savefig('W4_LR.png', dpi=300, bbox_inches="tight", transparent=False)

# %%
### Strong penalization
{'C': 0.01291549665014884, 'penalty': 'l1'}
{'C': 0.01291549665014884, 'penalty': 'l2'}
### Weak penalization
{'C': 100, 'penalty': 'l1'}
{'C': 100, 'penalty': 'l2'}

# %% [markdown]
# ### XGB

# %%
XGB = pd.read_csv('../Week4_XGBBurkPx_GridSearch.txt', sep='\t', index_col=0)
XGB['params2'] = XGB['params'].astype(str)
fig, ax = plt.subplots()
sns.boxplot(data=XGB, y= 'mean_test_score', x='params2', ax=ax)
plt.xticks(rotation=90)
fig.savefig('W4_XGB.png', dpi=300, bbox_inches="tight", transparent=False)
